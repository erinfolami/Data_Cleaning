# %%
import pandas as pd
import regex as re

df = pd.read_csv("new_df1.csv")

df = df.dropna(axis=0)

#This splits the data frame
split = df["score"].str.split(r"\s", n=-1,expand=True)

#This searches for letters that starts with uppercase
df["tone_name"] = df["score"].str.extract(r'([A-Z]\w+ *)')

df["score"]= split[1]


df["score"] = df['score'].str.replace(',','')
